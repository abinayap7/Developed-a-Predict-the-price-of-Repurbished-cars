# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Training_Data_Set.csv')

# %%
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# 1                  2012           7                 1242          51.0
# 2                  2014           5                 1995         105.0
# 3                  2011           8                 1618         140.0
# 4                  2012           7                 2993         180.0
# ...                 ...         ...                  ...           ...
# 53510              2014           5                 1598          77.0
# 53511              2009          10                 1900          77.0
# 53512              2015           4                 1995         105.0
# 53513              2011           8                11950          93.0
# 53514              2008          11                 2993         173.0
#
#       body_type  Vroom Audit Rating transmission  door_count  seat_count  \
# 0       compact                   8          man         NaN         NaN
# 1           NaN                   6          man         4.0         4.0
# 2           NaN                   7         auto         4.0         5.0
# 3           NaN                   7          man         4.0         5.0
# 4           NaN                   7         auto         4.0         5.0
# ...         ...                 ...          ...         ...         ...
# 53510       NaN                   4          man         4.0         5.0
# 53511       NaN                   8          man         5.0         5.0
# 53512       NaN                   4         auto         4.0         5.0
# 53513   compact                   5          man         NaN         NaN
# 53514       NaN                   4         auto         5.0         5.0
#
#       fuel_type       Price
# 0        petrol   543764.25
# 1        petrol   401819.25
# 2        diesel  2392855.50
# 3        petrol   958606.50
# 4        diesel  3085561.50
# ...         ...         ...
# 53510    diesel  1342996.50
# 53511    diesel   510732.75
# 53512    diesel  2008123.50
# 53513    diesel   874352.25
# 53514    diesel  1576610.25
#
# [53515 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
del df['body_type']

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
df['Distance '].mean()
# Out:
# 94546.2624464668

# %%
df['engine_power'].mean()
# Out:
# 100.44834472693755

# %%
df['door_count'].mean()
# Out:
# 3.973010591331202

# %%
df['seat_count'].mean()
# Out:
# 4.886099013421029

# %%
df['door_count'].fillna(df['door_count'].mean(),inplace=True)

# %%
df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)

# %%
df['engine_power'].fillna(df['engine_power'].mean(),inplace=True)

# %%
df['Distance '].fillna(df['Distance '].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53510    False
# 53511    False
# 53512    False
# 53513    False
# 53514    False
# Length: 53515, dtype: bool

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Maker']=le.fit_transform(df['Maker'])

# %%
df['model']=le.fit_transform(df['model'])

# %%
df['Location']=le.fit_transform(df['Location'])

# %%
df['Owner Type']=le.fit_transform(df['Owner Type'])

# %%
df['transmission']=le.fit_transform(df['transmission'])

# %%
df['fuel_type']=le.fit_transform(df['fuel_type'])

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int32
# model                    int32
# Location                 int32
# Distance               float64
# Owner Type               int32
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int32
# door_count             float64
# seat_count             float64
# fuel_type                int32
# Price                  float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
plt.show()

# %%
z=(df-df.mean())/df.std()

# %%
df1=df[(z>-2)&(z<2)]

# %%
df1.boxplot()
plt.show()

# %%
z=(df1-df1.mean())/df1.std()

# %%
df2=df1[(z>-2)&(z<2)]

# %%
df2.boxplot()
plt.show()

# %%
z=(df2-df2.mean())/df2.std()

# %%
df3=df2[(z>-2)&(z<2)]

# %%
df3.boxplot()
plt.show()

# %%
df3.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                4201
# Owner Type                 0
# manufacture_year        5832
# Age of car              5832
# engine_displacement     6224
# engine_power            6848
# Vroom Audit Rating         0
# transmission               0
# door_count             19707
# seat_count             14691
# fuel_type                  0
# Price                   6983
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#           Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 3      25004      5      6         9    43949.0           3            2011.0
# 5      25006      6      8         2    12015.0           0            2015.0
# 8      25009      5     13         3    17375.0           0            2015.0
# 13     25014      7      2         0       10.0           1            2015.0
# 16     25017      6     22         1      100.0           0            2015.0
# ...      ...    ...    ...       ...        ...         ...               ...
# 53498  78499      7      0         8    30028.0           0            2014.0
# 53500  78501      0     11         9   176200.0           3            2012.0
# 53503  78504      6     14         4    11033.0           0            2015.0
# 53505  78506      6     14         9       10.0           1            2015.0
# 53510  78511      6      8         4    29334.0           1            2014.0
#
#        Age of car  engine_displacement  engine_power  Vroom Audit Rating  \
# 3             8.0               1618.0         140.0                   7
# 5             4.0               1968.0         110.0                   4
# 8             4.0               1600.0          96.0                   5
# 13            4.0                998.0          51.0                   4
# 16            4.0               1197.0          81.0                   5
# ...           ...                  ...           ...                 ...
# 53498         5.0               1798.0          73.0                   4
# 53500         7.0               1968.0         120.0                   7
# 53503         4.0               1197.0          77.0                   5
# 53505         4.0               1197.0          77.0                   4
# 53510         5.0               1598.0          77.0                   4
#
#        transmission  door_count  seat_count  fuel_type       Price
# 3                 1         4.0         5.0          1   958606.50
# 5                 1         4.0         5.0          0  1543728.75
# 8                 1         4.0         5.0          0  1361480.25
# 13                1         4.0         5.0          1   772872.00
# 16                1         4.0         5.0          1  1171995.75
# ...             ...         ...         ...        ...         ...
# 53498             0         4.0         5.0          1  1323414.00
# 53500             1         4.0         5.0          0  1872357.75
# 53503             1         4.0         5.0          1   975541.50
# 53505             1         4.0         5.0          1   813120.00
# 53510             1         4.0         5.0          0  1342996.50
#
# [19804 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
dataframe=pd.DataFrame(ss.fit_transform(df3),columns=df3.columns)

# %%
dataframe
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.741119  0.057172 -0.853033  1.257946  -0.253431    1.335791
# 1     -1.740989  0.515568 -0.549499 -0.954155  -0.842655   -1.341560
# 2     -1.740795  0.057172  0.209334 -0.638140  -0.743756   -1.341560
# 3     -1.740470  0.973964 -1.460100 -1.586183  -1.064162   -0.449109
# 4     -1.740276  0.515568  1.575235 -1.270169  -1.062502   -1.341560
# ...         ...       ...       ...       ...        ...         ...
# 19799  1.729004  0.973964 -1.763633  0.941931  -0.510291   -1.341560
# 19800  1.729134 -2.234806 -0.094199  1.257946   2.186773    1.335791
# 19801  1.729328  0.515568  0.361101 -0.322126  -0.860774   -1.341560
# 19802  1.729458  0.515568  0.361101  1.257946  -1.064162   -0.449109
# 19803  1.729782  0.515568 -0.549499 -0.322126  -0.523096   -0.449109
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0             -0.374208    0.374208            -0.053888      2.070464
# 1              1.064157   -1.064157             1.023151      0.798736
# 2              1.064157   -1.064157            -0.109279      0.205263
# 3              1.064157   -1.064157            -1.961787     -1.702330
# 4              1.064157   -1.064157            -1.349413     -0.430601
# ...                 ...         ...                  ...           ...
# 19799          0.704566   -0.704566             0.500018     -0.769729
# 19800         -0.014617    0.014617             1.023151      1.222645
# 19801          1.064157   -1.064157            -1.349413     -0.600165
# 19802          1.064157   -1.064157            -1.349413     -0.600165
# 19803          0.704566   -0.704566            -0.115434     -0.600165
#
#        Vroom Audit Rating  transmission  door_count  seat_count  fuel_type  \
# 0                0.708691      0.551994         0.0         0.0   0.996069
# 1               -1.397705      0.551994         0.0         0.0  -1.003946
# 2               -0.695573      0.551994         0.0         0.0  -1.003946
# 3               -1.397705      0.551994         0.0         0.0   0.996069
# 4               -0.695573      0.551994         0.0         0.0   0.996069
# ...                   ...           ...         ...         ...        ...
# 19799           -1.397705     -1.811614         0.0         0.0   0.996069
# 19800            0.708691      0.551994         0.0         0.0  -1.003946
# 19801           -0.695573      0.551994         0.0         0.0   0.996069
# 19802           -1.397705      0.551994         0.0         0.0   0.996069
# 19803           -1.397705      0.551994         0.0         0.0  -1.003946
#
#           Price
# 0     -0.180077
# 1      1.215651
# 2      0.780923
# 3     -0.623121
# 4      0.328933
# ...         ...
# 19799  0.690121
# 19800  1.999551
# 19801 -0.139681
# 19802 -0.527115
# 19803  0.736832
#
# [19804 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
x=dataframe[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
       'fuel_type']]

# %%
y=dataframe['Price']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.7937356968882314

# %%
model.coef_
# Out:
# array([ 2.29427451e-03, -1.64285856e-01,  9.49725438e-02,  1.58735952e-03,
#        -3.73432063e-01,  2.31838706e-03,  1.71591146e-01, -1.71591146e-01,
#         1.13125350e-01,  4.57709816e-01,  3.03372658e-04, -1.15022391e-01,
#         0.00000000e+00,  0.00000000e+00, -1.49258069e-01])

# %%
model.intercept_
# Out:
# 1.7708387683490556e-15

# %%
y_predict=pd.DataFrame(model.predict(x))

# %%
y_predict
# Out:
#               0
# 0      0.606537
# 1      1.101632
# 2      0.813046
# 3     -0.757326
# 4      0.255639
# ...         ...
# 19799 -0.129267
# 19800  0.307566
# 19801 -0.003148
# 19802  0.077168
# 19803  0.100835
#
# [19804 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y,y_predict)

# %%
mse
# Out:
# 0.2062643031117686

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y,y_predict)

# %%
mae
# Out:
# 0.35891698225094676

# %%
df=pd.read_csv('Test_Data_Set.csv')

# %%
df
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                 2007          12                 1595          75.0
# 1                 2014           5                 1598          77.0
# 2                 2014           5                 1968         110.0
# 3                 2015           4                 1968         110.0
# 4                 2015           4                 1984         169.0
# ...                ...         ...                  ...           ...
# 5610              2011           8                 1968         103.0
# 5611              2005          14                 1896          96.0
# 5612              2005          14                 1896          77.0
# 5613              2011           8                 1997         104.0
# 5614              2011           8                 1396          80.0
#
#      body_type  Vroom Audit Rating transmission  door_count  seat_count  \
# 0          NaN                   5          man         4.0         5.0
# 1          NaN                   4          man         4.0         5.0
# 2          NaN                   5          man         5.0         5.0
# 3          NaN                   8         auto         4.0         5.0
# 4          NaN                   4         auto         2.0         NaN
# ...        ...                 ...          ...         ...         ...
# 5610       NaN                   8          man         4.0         5.0
# 5611       NaN                   6          man         4.0         5.0
# 5612       NaN                   7          man         5.0         5.0
# 5613       NaN                   5          man         4.0         7.0
# 5614       NaN                   4          man         NaN         NaN
#
#      fuel_type
# 0       petrol
# 1       diesel
# 2       diesel
# 3       diesel
# 4       petrol
# ...        ...
# 5610    diesel
# 5611    diesel
# 5612    diesel
# 5613    petrol
# 5614    petrol
#
# [5615 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type'],
#       dtype='object')

# %%
df['Distance '].mean()
# Out:
# 95890.0885729907

# %%
df['engine_power'].mean()
# Out:
# 99.47457315953736

# %%
del df['body_type']

# %%
df['seat_count'].mean()
# Out:
# 4.884843353090601

# %%
df['door_count'].mean()
# Out:
# 3.9783738823040133

# %%
df['door_count'].fillna(df['door_count'].mean(),inplace=True)

# %%
df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)

# %%
df['Distance '].fillna(df['Distance '].mean(),inplace=True)

# %%
df['engine_power'].fillna(df['engine_power'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5610    False
# 5611    False
# 5612    False
# 5613    False
# 5614    False
# Length: 5615, dtype: bool

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Maker']=le.fit_transform(df['Maker'])

# %%
df['model']=le.fit_transform(df['model'])

# %%
df['Location']=le.fit_transform(df['Location'])

# %%
df['Owner Type']=le.fit_transform(df['Owner Type'])

# %%
df['transmission']=le.fit_transform(df['transmission'])

# %%
df['fuel_type']=le.fit_transform(df['fuel_type'])

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int32
# model                    int32
# Location                 int32
# Distance               float64
# Owner Type               int32
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int32
# door_count             float64
# seat_count             float64
# fuel_type                int32
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
plt.show()

# %%
z=(df-df.mean())/df.std()

# %%
df1=df[(z>-2)&(z<2)]

# %%
df1.boxplot()
plt.show()

# %%
z=(df1-df1.mean())/df1.std()

# %%
df2=df1[(z>-2)&(z<2)]

# %%
df2.boxplot()
plt.show()

# %%
z=(df2-df2.mean())/df2.std()

# %%
df3=df2[(z>-2)&(z<2)]

# %%
df3.boxplot()
plt.show()

# %%
df3.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                472
# Owner Type                0
# manufacture_year        619
# Age of car              619
# engine_displacement     604
# engine_power            703
# Vroom Audit Rating        0
# transmission              0
# door_count             2032
# seat_count             1515
# fuel_type                 0
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#          Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0     11001      6      8         9   150000.0           0            2007.0
# 1     11002      6     14         3    29376.0           3            2014.0
# 3     11004      0     10         4     8650.0           1            2015.0
# 7     11008      0     10         1    18000.0           3            2014.0
# 9     11010      7      0         4     3000.0           3            2015.0
# ...     ...    ...    ...       ...        ...         ...               ...
# 5600  16601      1     19         4    72000.0           2            2008.0
# 5601  16602      3      5        10    20000.0           2            2015.0
# 5603  16604      1     19         9    95131.0           0            2011.0
# 5607  16608      6     16         9   162323.0           1            2012.0
# 5610  16611      6      8         9   149976.0           0            2011.0
#
#       Age of car  engine_displacement  engine_power  Vroom Audit Rating  \
# 0           12.0               1595.0          75.0                   5
# 1            5.0               1598.0          77.0                   4
# 3            4.0               1968.0         110.0                   8
# 7            5.0               1968.0         130.0                   6
# 9            4.0               1197.0          85.0                   5
# ...          ...                  ...           ...                 ...
# 5600        11.0               1995.0         130.0                   4
# 5601         4.0               1368.0          74.0                   4
# 5603         8.0               1995.0         135.0                   7
# 5607         7.0               1968.0         103.0                   7
# 5610         8.0               1968.0         103.0                   8
#
#       transmission  door_count  seat_count  fuel_type
# 0                1         4.0         5.0          1
# 1                1         4.0         5.0          0
# 3                0         4.0         5.0          0
# 7                0         4.0         5.0          0
# 9                1         4.0         5.0          1
# ...            ...         ...         ...        ...
# 5600             1         4.0         5.0          0
# 5601             1         4.0         5.0          1
# 5603             1         4.0         5.0          0
# 5607             0         4.0         5.0          0
# 5610             1         4.0         5.0          0
#
# [2386 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
dataframe1=pd.DataFrame(ss.fit_transform(df3),columns=df3.columns)

# %%
dataframe1
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.746124  0.615113 -0.568013  1.266712   1.796027   -1.278594
# 1    -1.745505  0.615113  0.375337 -0.646385  -0.455400    1.340055
# 2    -1.744267 -1.816128 -0.253563 -0.327536  -0.842247   -0.405711
# 3    -1.741790 -1.816128 -0.253563 -1.284084  -0.667731    1.340055
# 4    -1.740552  1.020319 -1.825814 -0.327536  -0.947704    1.340055
# ...        ...       ...       ...       ...        ...         ...
# 2381  1.721225 -1.410921  1.161462 -0.327536   0.340170    0.467172
# 2382  1.721844 -0.600508 -1.039688  1.585562  -0.630401    0.467172
# 2383  1.723083 -1.410921  1.161462  1.266712   0.771906   -1.278594
# 2384  1.725559  0.615113  0.689787  1.266712   2.026033   -0.405711
# 2385  1.727417  0.615113 -0.568013  1.266712   1.795579   -1.278594
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.918385    1.918385            -0.217790     -0.766701
# 1             0.610092   -0.610092            -0.208580     -0.687794
# 2             0.971303   -0.971303             0.927293      0.614178
# 3             0.610092   -0.610092             0.927293      1.403252
# 4             0.971303   -0.971303            -1.439621     -0.372164
# ...                ...         ...                  ...           ...
# 2381         -1.557174    1.557174             1.010181      1.403252
# 2382          0.971303   -0.971303            -0.914663     -0.806155
# 2383         -0.473541    0.473541             1.010181      1.600520
# 2384         -0.112330    0.112330             0.927293      0.338002
# 2385         -0.473541    0.473541             0.927293      0.338002
#
#       Vroom Audit Rating  transmission  door_count  seat_count  fuel_type
# 0              -0.717653      0.643045         0.0         0.0   1.127999
# 1              -1.429637      0.643045         0.0         0.0  -0.886526
# 2               1.418298     -1.555101         0.0         0.0  -0.886526
# 3              -0.005670     -1.555101         0.0         0.0  -0.886526
# 4              -0.717653      0.643045         0.0         0.0   1.127999
# ...                  ...           ...         ...         ...        ...
# 2381           -1.429637      0.643045         0.0         0.0  -0.886526
# 2382           -1.429637      0.643045         0.0         0.0   1.127999
# 2383            0.706314      0.643045         0.0         0.0  -0.886526
# 2384            0.706314     -1.555101         0.0         0.0  -0.886526
# 2385            1.418298      0.643045         0.0         0.0  -0.886526
#
# [2386 rows x 15 columns]

# %%
df3.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type'],
#       dtype='object')

# %%
x_test=dataframe1[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
       'fuel_type']]

# %%
y_test_predict=pd.DataFrame(model.predict(x_test))

# %%
y_test_predict.shape
# Out:
# (2386, 1)

# %%
Final=pd.concat([dataframe1['Id'],y_test_predict],axis=1)

# %%
Final
# Out:
#             Id         0
# 0    -1.746124 -2.107119
# 1    -1.745505  0.031619
# 2    -1.744267  1.614315
# 3    -1.741790  1.788453
# 4    -1.740552 -0.230942
# ...        ...       ...
# 2381  1.721225  0.499671
# 2382  1.721844 -0.139008
# 2383  1.723083  0.799758
# 2384  1.725559 -0.254636
# 2385  1.727417 -0.666634
#
# [2386 rows x 2 columns]

# %%
Final.to_csv('car price prediction.csv')
